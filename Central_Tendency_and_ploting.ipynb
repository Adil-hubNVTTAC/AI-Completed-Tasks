# %% [markdown]
# <a href="https://colab.research.google.com/github/Adil-hubNVTTAC/AI-Completed-Tasks/blob/main/Central_Tendency_and_ploting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#file_path = r"D:\NAVTTAC\Daily Completed Tasks\Temperature_Data_Sheet.csv"
#df = pd.read_csv(file_path)

# %%
import os
#file_path = r'D:\NAVTTAC\Daily Completed Tasks\Temperature_Data_Sheet.xlsx'
#os.chdir(r"D:\NAVTTAC\Daily Completed Tasks\Temperature_Data_Sheet.xlsx")
#file_path = "Temperature_Data_Sheet.xlsx"
file_path = "/content/Temperature_Data_Sheet.csv"
pd.read_csv(file_path)
# Out:
#       Temperature - (Celsius)   Year      Month
# 0                     7.72768   1901    January
# 1                     8.93600   1901   February
# 2                    16.96320   1901      March
# 3                    21.27410   1901      April
# 4                    26.04970   1901        May
# ...                       ...    ...        ...
# 1387                 27.63320   2016     August
# 1388                 26.71790   2016  September
# 1389                 22.39820   2016    October
# 1390                 15.76720   2016   November
# 1391                 12.87630   2016   December
#
# [1392 rows x 3 columns]

# %%
df.describe()
#Fetch the column(lines of code)
#print(df['Celsius'])
# Out:
#        Temperature - (Celsius)         Year
# count              1392.000000  1392.000000
# mean                 20.007129  1958.500000
# std                   7.377193    33.497105
# min                   5.913480  1901.000000
# 25%                  13.119875  1929.750000
# 50%                  21.170700  1958.500000
# 75%                  27.211500  1987.250000
# max                  30.305800  2016.000000

# %%
df.columns
# Out:
# Index(['Temperature - (Celsius)', ' Year', 'Month'], dtype='object')

# %%
df['Temperature - (Celsius)']
#df[' Year']
#df[]
# Out:
# 0        7.72768
# 1        8.93600
# 2       16.96320
# 3       21.27410
# 4       26.04970
#           ...
# 1387    27.63320
# 1388    26.71790
# 1389    22.39820
# 1390    15.76720
# 1391    12.87630
# Name: Temperature - (Celsius), Length: 1392, dtype: float64

# %%
from scipy import stats
# Select the 'Temperature' column
temp_data = df['Temperature - (Celsius)']

# Calculate mean, median, and mode
mean_temp = temp_data.mean()
median_temp = temp_data.median()
mode_temp = temp_data.mode()[0]  # Mode can have multiple values, we take the first one

# Print the calculated values
print(f"Mean Temperature: {mean_temp}")
print(f"Median Temperature: {median_temp}")
print(f"Mode Temperature: {mode_temp}")

# Plotting the boxplot for the 'Price' column
plt.figure(figsize=(10, 6))
sns.boxplot(x=temp_data)
plt.title('Boxplot of Temperature in Celsius')
plt.xlabel('Temperature')
plt.ylabel('Year')
plt.show()  # Display the plot

# Add mean, median, and mode to the plot
plt.axvline(mean_temp, color='r', linestyle='--', label=f'Mean: {mean_temp:.2f}')
plt.axvline(median_temp, color='g', linestyle='-', label=f'Median: {median_temp:.2f}')
plt.axvline(mode_temp, color='b', linestyle='-.', label=f'Mode: {mode_temp:.2f}')
plt.legend()

plt.show()
# Out:
# Mean Temperature: 20.007129439655174
# Median Temperature: 21.1707
# Mode Temperature: 20.5152

# %%
temp_data = df['Temperature - (Celsius)']
#temp_data1 = df['Years']
# create a figure
plt.figure(figsize=(20, 5))
x = range(df['Temperature - (Celsius)'].size)
y = df['Temperature - (Celsius)']
plt.scatter(x, y, marker='x', s=0.5)
# also need to make the figure readable -- very important from stats perspective!
plt.title("Yearly Temperature in Celsius")
plt.xlabel("Year")
plt.ylabel("Temperature - (Celsius)")
plt.show()

# %%
# Select the 'Temperature - (Celsius)' column
temp_data = df['Temperature - (Celsius)']

# Calculate mean and standard deviation
mean_temp = temp_data.mean()
std_dev_temp = temp_data.std()

# Print the calculated values
print(f"Mean Price: {mean_temp}")
print(f"Standard Deviation: {std_dev_temp}")

# Plotting the histogram for the 'Price' column
plt.figure(figsize=(10, 6))
sns.histplot(temp_data.dropna(), bins=30, kde=False, color='skyblue', edgecolor='black')
plt.title("Yearly Temperature in Celsius")
plt.xlabel("Year")
plt.ylabel("Temperature - (Celsius)")

# Add mean and standard deviation lines to the plot
plt.axvline(mean_temp, color='r', linestyle='--', linewidth=2, label=f'Mean: {mean_temp:.2f}')
plt.axvline(mean_temp + std_dev_temp, color='g', linestyle='--', linewidth=2, label=f'Mean + 1 SD: {mean_temp + std_dev_temp:.2f}')
plt.axvline(mean_temp - std_dev_temp, color='g', linestyle='--', linewidth=2, label=f'Mean - 1 SD: {mean_temp - std_dev_temp:.2f}')
plt.legend()

plt.show()
# Out:
# Mean Price: 20.007129439655174
# Standard Deviation: 7.377192752035829
